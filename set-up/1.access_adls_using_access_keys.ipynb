# %% [markdown]
# ## Access Azure Data Lake using access keys

# %%
# formula1_account_key = dbutils.secrets.get(scope = "formula1-scope", key = "formula1dl-account-key")

# %%
# spark.conf.set("fs.azure.account.key.formula1dlmariama.dfs.core.windows.net", formula1_account_key)

# %%
display(dbutils.fs.ls("abfss://demo@formula1dlmariama.dfs.core.windows.net"))

# %%
display(spark.read.csv("abfss://demo@formula1dlmariama.dfs.core.windows.net/circuits.csv"))
