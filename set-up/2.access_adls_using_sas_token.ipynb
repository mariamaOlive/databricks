# %% [markdown]
# ## Access Azure Data Lake using SAS token

# %%
spark.conf.set("fs.azure.account.auth.type.formula1dlmariama.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.formula1dlmariama.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.formula1dlmariama.dfs.core.windows.net", "sp=rl&st=2025-10-03T23:01:32Z&se=2025-10-04T07:16:32Z&spr=https&sv=2024-11-04&sr=c&sig=wHKZpP9Dm2aRowgWVe3oXKmdl0ishoHZMM%2FAXUQrU94%3D")

# %%
display(dbutils.fs.ls("abfss://demo@formula1dlmariama.dfs.core.windows.net"))

# %%
display(spark.read.csv("abfss://demo@formula1dlmariama.dfs.core.windows.net/circuits.csv"))
